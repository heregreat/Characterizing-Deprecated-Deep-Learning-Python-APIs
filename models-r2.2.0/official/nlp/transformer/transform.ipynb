# %%
! sudo rm -rf /home/nianliu/transformer/model_big
! python3 transformer_main.py --data_dir=$DATA_DIR --model_dir=$MODEL_DIR \
    --vocab_file=$VOCAB_FILE --param_set=$PARAM_SET \
    --train_steps=1000 \
    --batch_size=1024 --max_length=64 \
    --num_gpus=4 --enable_time_history=false enable_checkpointing=false | tee transform1_new.log
# Out:
# 2020-07-20 17:32:08.473213: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-07-20 17:32:11.641665: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-20 17:32:14.076274: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-20 17:32:14.077244: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# ...

# %%
! sudo rm -rf /home/nianliu/transformer/model_big
! python3 transformer_main.py --data_dir=$DATA_DIR --model_dir=$MODEL_DIR \
    --vocab_file=$VOCAB_FILE --param_set=$PARAM_SET \
    --train_steps=1000 \
    --batch_size=1024 --max_length=64 \
    --num_gpus=4 --enable_time_history=false enable_checkpointing=false | tee transform2_new.log

# %%
! sudo rm -rf /home/nianliu/transformer/model_big
! python3 transformer_main.py --data_dir=$DATA_DIR --model_dir=$MODEL_DIR \
    --vocab_file=$VOCAB_FILE --param_set=$PARAM_SET \
    --train_steps=1000 \
    --batch_size=1024 --max_length=64 \
    --num_gpus=4 --enable_time_history=false enable_checkpointing=false | tee transform3_new.log

# %%
! sudo rm -rf /home/nianliu/transformer/model_big
! python3 transformer_main.py --data_dir=$DATA_DIR --model_dir=$MODEL_DIR \
    --vocab_file=$VOCAB_FILE --param_set=$PARAM_SET \
    --train_steps=1000 \
    --batch_size=1024 --max_length=64 \
    --num_gpus=4 --enable_time_history=false enable_checkpointing=false | tee transform4_new.log

# %%
! sudo rm -rf /home/nianliu/transformer/model_big
! python3 transformer_main.py --data_dir=$DATA_DIR --model_dir=$MODEL_DIR \
    --vocab_file=$VOCAB_FILE --param_set=$PARAM_SET \
    --train_steps=1000 \
    --batch_size=1024 --max_length=64 \
    --num_gpus=4 --enable_time_history=false enable_checkpointing=false | tee transform5_new.log

# %%
! sudo rm -rf /home/nianliu/transformer/model_big
! python3 transformer_main.py --data_dir=$DATA_DIR --model_dir=$MODEL_DIR \
    --vocab_file=$VOCAB_FILE --param_set=$PARAM_SET \
    --train_steps=1000 \
    --batch_size=1024 --max_length=64 \
    --num_gpus=4 --enable_time_history=false enable_checkpointing=false | tee transform6_new.log

# %%
! sudo rm -rf /home/nianliu/transformer/model_big
! python3 transformer_main.py --data_dir=$DATA_DIR --model_dir=$MODEL_DIR \
    --vocab_file=$VOCAB_FILE --param_set=$PARAM_SET \
    --train_steps=1000 \
    --batch_size=1024 --max_length=64 \
    --num_gpus=4 --enable_time_history=false enable_checkpointing=false | tee transform7_new.log

# %%
! sudo rm -rf /home/nianliu/transformer/model_big
! python3 transformer_main.py --data_dir=$DATA_DIR --model_dir=$MODEL_DIR \
    --vocab_file=$VOCAB_FILE --param_set=$PARAM_SET \
    --train_steps=1000 \
    --batch_size=1024 --max_length=64 \
    --num_gpus=4 --enable_time_history=false enable_checkpointing=false | tee transform8_new.log

# %%
! sudo rm -rf /home/nianliu/transformer/model_big
! python3 transformer_main.py --data_dir=$DATA_DIR --model_dir=$MODEL_DIR \
    --vocab_file=$VOCAB_FILE --param_set=$PARAM_SET \
    --train_steps=1000 \
    --batch_size=1024 --max_length=64 \
    --num_gpus=4 --enable_time_history=false enable_checkpointing=false | tee transform9_new.log

# %%
! sudo rm -rf /home/nianliu/transformer/model_big
! python3 transformer_main.py --data_dir=$DATA_DIR --model_dir=$MODEL_DIR \
    --vocab_file=$VOCAB_FILE --param_set=$PARAM_SET \
    --train_steps=1000 \
    --batch_size=1024 --max_length=64 \
    --num_gpus=4 --enable_time_history=false enable_checkpointing=false | tee transform10_new.log
